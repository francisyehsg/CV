# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("../assets/thor.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x2370D0E2948>

# %%
cut = arr[2:80, 90:140]  # cropping

# %%
plt.imshow(cut)

# %%
plt.imshow(arr)

# %%
work = arr.copy()

# %%
work[:, :, [1, 2]] = 0

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray)
